# %% [markdown]
# #### Getting started With Langchain And Open AI
#
# In this quickstart we'll see how to:
#
# - Get setup with LangChain, LangSmith and LangServe
# - Use the most basic and common components of LangChain: prompt templates, models, and output parsers.
# - Build a simple application with LangChain
# - Trace your application with LangSmith
# - Serve your application with LangServe

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['OPENAI_API_KEY']=os.getenv("OPENAI_API_KEY")
## Langsmith Tracking
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(
    model="gemma2:2b"
)

# %%
## Input and get response form LLM

result=llm.invoke("What is generative AI?")

# %%
print(result)
# Out:
# content="Generative AI is a type of artificial intelligence (AI) that focuses on creating new content, rather than just analyzing or classifying existing content.  \n\nHere's a breakdown:\n\n**What it does:**\n\n* **Generates content:**  It can create text, images, audio, video, code, 3D models, and more based on the data it has been trained on. \n* **Mimics human creativity:** It learns patterns and relationships in data, and uses that knowledge to generate new and original outputs.\n* **Expands possibilities:** It opens up new avenues for creative expression, automation, and problem-solving.\n\n**How it works:**\n\n* **Machine learning:**  Generative AI models are based on machine learning algorithms, particularly deep learning techniques. These algorithms are trained on massive amounts of data to learn the underlying patterns and structures of the data. \n* **Neural networks:**  These networks are designed with layers of interconnected nodes that process information, allowing the model to recognize and generate new outputs. \n\n**Examples of Generative AI:**\n\n* **Text generation:** ChatGPT, Bard, Jasper, and other AI writing tools can generate different kinds of text, from articles and emails to poems and scripts.\n* **Image generation:** DALL-E 2, Midjourney, and Stable Diffusion can create realistic and artistic images based on text descriptions.\n* **Audio generation:**  AI can generate music, voiceovers, and sound effects. \n* **Video generation:**  Tools like Runway ML can create videos from raw data, even if the source material is only text prompts.\n* **Code generation:**  AI can assist with coding by generating code snippets and even complete programs.\n\n**Applications of Generative AI:**\n\n* **Content creation:**  Generate marketing materials, social media posts, and website content.\n* **Entertainment:**  Create art, music, and games.\n* **Education:**  Develop personalized learning experiences.\n* **Research:**  Accelerate scientific discoveries and drug development.\n* **Business:**  Automate tasks, personalize customer experiences, and create new products.\n\n\n**Key Takeaways:**\n\n* **Generative AI is a powerful technology with transformative potential.** \n* **It's still in development, but it's rapidly evolving.**  \n* **The ethical implications of AI need careful consideration.**  \n\nIt's important to stay informed about the latest developments in generative AI and to use this technology responsibly and ethically. \n" additional_kwargs={} response_metadata={'model': 'gemma2:2b', 'created_at': '2026-03-06T13:30:44.5165845Z', 'done': True, 'done_reason': 'stop', 'total_duration': 81613912100, 'load_duration': 5319036600, 'prompt_eval_count': 14, 'prompt_eval_duration': 886062400, 'eval_count': 515, 'eval_duration': 74834094000, 'logprobs': None, 'model_name': 'gemma2:2b', 'model_provider': 'ollama'} id='lc_run--019cc356-aa9b-7352-afc4-144013d392e3-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 14, 'output_tokens': 515, 'total_tokens': 529}

# %%
### Chatprompt Template
from langchain_core.prompts import ChatPromptTemplate

prompt=ChatPromptTemplate.from_messages(
    [
        ("system","You are an expert AI Engineer. Provide me answers based on the questions"),
        ("user","{input}")
    ]

)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Engineer. Provide me answers based on the questions'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
## chain 
chain=prompt|llm

response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# content="Let's talk about Langsmith!  \n\n**What is Langsmith?**\n\nLangsmith is a powerful and cutting-edge AI model designed to **understand and create human-like text**. It's particularly adept at:\n\n* **Text Generation:**  Langsmith can generate various creative text formats, including articles, stories, poems, summaries, dialogues, and more. \n* **Text Completion:** It can predict and complete texts, like writing sentences or paragraphs based on the context you provide.\n* **Text Translation:** Langsmith can translate between languages with accuracy and fluency.\n* **Text Summarization:** It can condense large amounts of text into concise summaries.\n* **Answering Questions:** Langsmith can answer your questions based on the information it has been trained on.\n\n**How does Langsmith work?**\n\nLangsmith is trained on a vast dataset of human text, allowing it to:\n\n* **Learn patterns:**  It learns the grammar, vocabulary, and sentence structure of language.\n* **Understand context:**  It can analyze the meaning of words in relation to their surrounding context. \n* **Generate new text:**  Based on its training, it can use its learned knowledge to create new and interesting text.\n\n**Benefits of using Langsmith:**\n\n* **Efficiency:**  It can automate tasks that would normally require human effort, saving time and resources. \n* **Creativity:**  It can help you explore new ideas and concepts and generate original content. \n* **Accuracy:**  Langsmith can generate high-quality text that is free of grammatical errors and typos. \n* **Accessibility:**  It makes content creation accessible to those who might not have the skills or time to write themselves.\n\n**Where can you find Langsmith?**\n\nLangsmith is a product of a team of AI researchers and engineers at Google AI. It is designed to be used by individuals and organizations alike. You can typically find Langsmith through:\n\n* **API access:**  Developers can integrate Langsmith into their own applications and services. \n* **Open-source projects:** Some projects leverage Langsmith for various purposes. \n* **Pre-built demos:**  Langsmith is often showcased in interactive demos where you can directly experience its capabilities. \n\n\n**Keep in mind:**\n\n* Langsmith is still under development, so it's continually evolving and improving. \n* While impressive, it's important to remember that Langsmith is an AI, not a human writer.  It needs proper guidance and prompts to produce the best results. \n\nI hope this overview of Langsmith is helpful!  Let me know if you have any more questions about Langsmith, or if you'd like to explore a specific use case. \n" additional_kwargs={} response_metadata={'model': 'gemma2:2b', 'created_at': '2026-03-06T13:32:20.6418348Z', 'done': True, 'done_reason': 'stop', 'total_duration': 78320215100, 'load_duration': 276993600, 'prompt_eval_count': 36, 'prompt_eval_duration': 1727773700, 'eval_count': 571, 'eval_duration': 75766519000, 'logprobs': None, 'model_name': 'gemma2:2b', 'model_provider': 'ollama'} id='lc_run--019cc358-2f2e-7433-8484-62fdeae24a9e-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 36, 'output_tokens': 571, 'total_tokens': 607}

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
## stroutput Parser

from langchain_core.output_parsers import StrOutputParser
output_parser=StrOutputParser()
chain=prompt|llm|output_parser

response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# Let's talk about Langsmith!
#
# **Langsmith: A powerful and accessible solution for creating and controlling language-based AI models**
#
# Langsmith is a cutting-edge tool that offers a unique combination of power and accessibility, making it a game-changer for AI developers and users alike. Here's a breakdown of its key features:
#
# **1. Powerful and Easy-to-use Interface:**
#
# * **Intuitive Design:** Langsmith boasts a user-friendly interface, making it accessible to developers with varying levels of expertise.
# * **Fine-Tuned Models:** It allows you to fine-tune pre-trained language models, tailoring them to specific tasks and datasets. This is critical for achieving the desired level of accuracy and performance.
# * **Focus on Simplicity:** Langsmith prioritizes straightforward workflows, enabling rapid experimentation and development.
#
# **2.  Wide-ranging Capabilities:**
#
# * **Text Generation:**  Langsmith excels at generating high-quality text in various styles and formats, from creative writing to technical documentation.
# * **Summarization:** The ability to condense large amounts of information into concise summaries makes Langsmith a valuable tool for information management and analysis.
# * **Translation:** Langsmith supports language translation, facilitating seamless communication across different linguistic barriers.
# * **Code Generation:**  You can use Langsmith to generate code in various programming languages, significantly accelerating software development.
#
# **3.  Key Advantages:**
#
# * **Reduced Development Time:** Langsmith's user-friendly interface and pre-trained models significantly reduce development time and complexity.
# * **Improved Accuracy and Efficiency:**  Fine-tuning models for specific tasks ensures higher accuracy and faster results compared to relying on generic models.
# * **Open Source:** Langsmith's open-source nature fosters collaboration and innovation within the AI community.
#
# **4.  Challenges and Considerations:**
#
# * **Data Requirements:**  Like most AI models, Langsmith requires large datasets for effective training and fine-tuning.
# * **Ethical Considerations:**  The potential for bias in language models needs to be carefully addressed during development and deployment.
#
# **Who is Langsmith Ideal For?**
#
# * **Beginners and Professionals:** Langsmith offers a great entry point for those new to the world of AI while being robust enough for experienced developers.
# * **Businesses and Organizations:** Langsmith's text generation and automation capabilities can boost efficiency and communication across different departments.
# * **Researchers and Students:** Langsmith provides an ideal platform for exploring and experimenting with AI language models.
#
#
# **Want to explore Langsmith further?**  Here's where you can start:
#
# * **Langsmith Website:**  [https://langsmith.ai](https://langsmith.ai)  - Check out the website for documentation, tutorials, and a free trial.
# * **GitHub Repository:** [https://github.com/langsmith-ai](https://github.com/langsmith-ai) - Get a closer look at the code and participate in the open-source community.
#
# **Let me know if you have more questions or would like to delve deeper into a specific aspect of Langsmith!**
